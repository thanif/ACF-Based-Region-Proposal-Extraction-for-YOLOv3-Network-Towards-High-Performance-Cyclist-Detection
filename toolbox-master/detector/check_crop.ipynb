# %%
import matplotlib.pyplot as plt
import cv2
% matplotlib inline

# %%
im = cv2.imread("/media/talha/73fb317f-f61e-4b1f-b59e-5121d06d212b/Code(ACF)/data/Tsinghua-Daimler/test/check_img/tsinghuaDaimlerDataset_2014-12-04_082614_000018089.png")
plt.imshow(im)

# %%
plt.imshow(im[414:414+76,536:536+31])

# %%
p1 = im[60:60+832,24:24+832]
plt.imshow(p1)

# %%
plt.imshow(p1[355:355+76,512:512+31])

# %%
im = cv2.imread("/media/talha/73fb317f-f61e-4b1f-b59e-5121d06d212b/Code(ACF)/data/Tsinghua-Daimler/test/check_img/tsinghuaDaimlerDataset_2014-12-04_082614_000018089_1.jpg")
plt.imshow(im)

# %%
p1 = im[60:60+832,858:858+832]
plt.imshow(p1)

# %%
im = cv2.imread("/media/talha/73fb317f-f61e-4b1f-b59e-5121d06d212b/Code(ACF)/data/Tsinghua-Daimler/test/check_img/tsinghuaDaimlerDataset_2014-12-04_082614_000018089_2.jpg")
plt.imshow(im)
