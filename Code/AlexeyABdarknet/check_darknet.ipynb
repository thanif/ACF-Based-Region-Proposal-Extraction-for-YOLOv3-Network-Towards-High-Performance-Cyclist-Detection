# %%
import darknet

# %%
output = darknet.performDetect(imagePath="data/dog.jpg", thresh= 0.25, configPath = "./cfg/yolov3.cfg", weightPath = "yolov3.weights", metaPath= "./cfg/coco.data", showImage= True, makeImageOnly = False, initOnly= False)
# Out:
# *** 3 Results, color coded by confidence ***
# dog: 100.0%
# bicycle: 99.0%
# truck: 93.0%

# %%
output.keys()
# Out:
# ['caption', 'detections', 'image']

# %%
output['caption']
# Out:
# 'dog: 100.0%\n<br/>bicycle: 99.0%\n<br/>truck: 93.0%'

# %%
output['detections']
# Out:
# [('dog',
#   0.9978048205375671,
#   (222.03924560546875,
#    383.3959655761719,
#    196.37692260742188,
#    320.160888671875)),
#  ('bicycle',
#   0.989617645740509,
#   (343.343505859375,
#    278.59149169921875,
#    450.0836181640625,
#    309.04913330078125)),
#  ('truck',
#   0.9329841136932373,
#   (582.3942260742188,
#    126.67134857177734,
#    216.78005981445312,
#    79.34504699707031))]

# %%
len(output['detections'])
# Out:
# 3

# %%
output['detections'][0][2]
# Out:
# (222.03924560546875, 383.3959655761719, 196.37692260742188, 320.160888671875)
